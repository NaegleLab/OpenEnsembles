# %%
import pandas as pd
import openensembles as oe
import numpy as np

fileName = 'data_example.csv'
df = pd.DataFrame.from_csv(fileName)
x = [0, 5, 30]
dataObj = oe.data(df, x)

# %%
dataObj.D['parent']
# Out:
# array([[ 0. ,  1. ,  1. ],
#        [ 0.5,  0.5,  0.5],
#        [ 1. ,  1. ,  0. ]])

# %%
dataObj.transforms_available()
# Out:
# {'log': '', 'minmax': '', 'zscore': ''}

# %%
dataObj.transform('parent', 'zscore', 'zscore')
dataObj.D['zscore']
# Out:
# WARNING: transformation zscore resulted in 3 NaN values
# array([[-1.41421356,  0.70710678,  0.70710678],
#        [        nan,         nan,         nan],
#        [ 0.70710678,  0.70710678, -1.41421356]])

# %%
dataObj.transform('parent', 'zscore', 'zscore_noKeep', Keep_NaN=0)
dataObj.D.keys()
# Out:
# WARNING: transformation zscore resulted in 3 NaN values
# Transformation zscore resulted in 3 NaN values, and you requested not to keep a transformation with NaNs
# ['zscore', 'parent']

# %%
dataObj.transform('parent', 'minmax', 'minmax')
dataObj.D['minmax']
# Out:
# array([[ 0.,  1.,  1.],
#        [ 0.,  0.,  0.],
#        [ 1.,  1.,  0.]])

# %%
dataObj.transform('parent', 'log', 'log_default')
dataObj.D['log_default']
# Out:
# DEBUG base is 2
# WARNING: transformation log resulted in 2 Inf values
# array([[-inf,   0.,   0.],
#        [ -1.,  -1.,  -1.],
#        [  0.,   0., -inf]])

# %%
dataObj.transform('parent', 'log', 'log_10', base=int(10))
dataObj.D['log_10']
# Out:
# DEBUG base is 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c40688a7ff2d> in <module>()
# ----> 1 dataObj.transform('parent', 'log', 'log_10', base=int(10))
#       2 dataObj.D['log_10']
#
# /Users/knaegle/GIT/openensembles.main/openensembles.pyc in transform(self, source_name, txfm_fcn, txfm_name, **kwargs)
#      76         txfm = tx.transforms(self.x[source_name], self.D[source_name], kwargs)
#      77         func = getattr(txfm,txfm_fcn)
# ---> 78         func()
#      79
#      80         #### FINAL staging, X, D and var_params have been set in transform block, now add each
#
# /Users/knaegle/GIT/openensembles.main/transforms.py in log(self)
#      85                 self.data_out = np.log2(self.data)
#      86             else:
# ---> 87                 raise ValueError('Requested base for logarithm was not recognized as either e, 2, or 10)')
#      88         else:
#      89                 raise ValueError('Requested base for logarithm was not recognized as either int or string for e, 2, or 10)')
#
# ValueError: Requested base for logarithm was not recognized as either e, 2, or 10)

# %%
dataObj.transform('parent', 'logldldkldfklj', 'log_default')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-04e1d061cf0b> in <module>()
# ----> 1 dataObj.transform('parent', 'logldldkldfklj', 'log_default')
#
# /Users/knaegle/GIT/openensembles.main/openensembles.pyc in transform(self, source_name, txfm_fcn, txfm_name, **kwargs)
#      69         ######BEGIN TXFM BLOCK  ######
#      70         if txfm_fcn not in TXFM_FCN_DICT:
# ---> 71             raise ValueError( "The transform function you requested does not exist, currently the following are supported %s"%(TXFM_FCN_DICT.keys()))
#      72
#      73         txfm = tx.transforms(self.x[source_name], self.D[source_name], kwargs)
#
# ValueError: The transform function you requested does not exist, currently the following are supported ['minmax', 'zscore', 'log']

# %%
dataObj.transform('parent', 'minmax', 'minmaxRangeDiff', minValue=-1, maxValue=1)
dataObj.D['minmaxRangeDiff']
# Out:
# array([[-1.,  1.,  1.],
#        [-1., -1., -1.],
#        [ 1.,  1., -1.]])

# %%
dataObj.transform('parent', 'minmax', 'minmaxRangeDiff', minValue=1, maxValue=-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-e28323f1b910> in <module>()
# ----> 1 dataObj.transform('parent', 'minmax', 'minmaxRangeDiff', minValue=1, maxValue=-1)
#
# /Users/knaegle/GIT/openensembles.main/openensembles.pyc in transform(self, source_name, txfm_fcn, txfm_name, **kwargs)
#      75                 txfm.zscore()
#      76         elif txfm_fcn == 'minmax':
# ---> 77                 txfm.minmax()
#      78
#      79
#
# /Users/knaegle/GIT/openensembles.main/transforms.pyc in minmax(self)
#      56
#      57         if minValue > maxValue:
# ---> 58             raise ValueError("Your requested minValue (%0.2f) is larger than the maximum value (%0.2f)"%(minValue, maxValue))
#      59
#      60         self.x_out = self.x
#
# ValueError: Your requested minValue (1.00) is larger than the maximum value (-1.00)
